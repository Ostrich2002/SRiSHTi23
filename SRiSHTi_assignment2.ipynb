# %% [markdown]
# <a href="https://colab.research.google.com/github/Ostrich2002/SRiSHTi23/blob/main/DataMounting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

df = pd.read_csv('/content/gdrive/MyDrive/DATA/IRIS.csv')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
plt.scatter(df['sepal_length'], df['sepal_width'])
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.title('Scatter Plot: Sepal Length vs Sepal Width')
plt.show()

# %%
plt.scatter(df['petal_length'], df['petal_width'])
plt.show()

# %%
plt.scatter(df['petal_length'], df['sepal_length'])

# %%
plt.scatter(df['petal_length'], df['sepal_width'])

# %%
plt.scatter(df['sepal_length'], df['petal_width'])

# %%
plt.scatter(df['petal_width'], df['sepal_width'])

# %% [markdown]
# **Analysis about the dtaset **
#
# 1. petal height and width show more distinct patterns so these two features are more important in predicting the class
# 2. There is positive correlation between sepal length and sepal width
# 3. There are three distinct species: setosa, versicolor, and virginica. Each species exhibits different ranges and distributions of sepal and petal measurements
# 4. We can build classification models to predict species of iris flower based on their petal and sepal measurements.
